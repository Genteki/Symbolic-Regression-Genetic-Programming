# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from symbolic_node import *
from utils import *
sns.set_style("whitegrid")

# %%
root.all_node
# Out:
# []

# %%
a = 2
type(a)
# Out:
# int

# %%
with open("data/data.txt") as ifile:
    lines = ifile.readlines()
    pts = np.array([line.strip().split(",") for line in lines],
                   dtype=np.float32)
x = pts[:,0]
y = pts[:,1]

# %% [markdown]
# ## Random Search

# %%
def random_search(max_degree=4):
    root = SymbolicNode()
    root.random_grow()
    y_predict = root.post_order_traverse_recursive(x)
    mae = np.mean(np.abs(y - y_predict))
    return mae, root.copy()

# %%
N = 1000
best_mae = 100000
best_s = None
hist_mae = []
for i in range(N):
    (mae, root) = random_search()
    if mae <= best_mae:
        best_mae = mae
        best_s = root
    hist_mae.append(best_mae)
print(best_s)
print(best_mae)
# Out:
# /Users/genteki/genteki's document/MECS4510 Evolutionary Computation & Design Automation/hw2/symbolic_node.py:23: RuntimeWarning: divide by zero encountered in divide
#   return self.f(
# /Users/genteki/genteki's document/MECS4510 Evolutionary Computation & Design Automation/hw2/symbolic_node.py:21: RuntimeWarning: invalid value encountered in sin
#   return self.f(self.lchild.post_order_traverse_recursive(x))
# /Users/genteki/genteki's document/MECS4510 Evolutionary Computation & Design Automation/hw2/symbolic_node.py:23: RuntimeWarning: invalid value encountered in subtract
#   return self.f(
# /Users/genteki/genteki's document/MECS4510 Evolutionary Computation & Design Automation/hw2/symbolic_node.py:21: RuntimeWarning: invalid value encountered in cos
#   return self.f(self.lchild.post_order_traverse_recursive(x))
# /Users/genteki/genteki's document/MECS4510 Evolutionary Computation & Design Automation/hw2/symbolic_node.py:23: RuntimeWarning: invalid value encountered in divide
#   return self.f(
# (cos(sin(cos(x)))/(8.974252082187324-cos(cos((4.191288359867556*((sin(((-4.437842679279697-x)+(x/-1.0499276070239087)))/sin(cos(x)))+((((x*x)/(5.08447610966825*-8.955103279272565))+cos((-1.0195225528049043*-9.923397664020914)))*(((x*x)*(x-x))+cos(cos(4.875479623435288))))))))))
# 0.3685745

# %%
plt.figure(figsize=(6,4))
ax = plt.subplot(1,1,1)
ax.plot(np.arange(N), hist_mae)
ax.set_ylim(0,2)
ax.set_xlim(-N/100,N)
ax.set_xlabel("Evaluations")
ax.set_ylabel("MAE")
plt.savefig("output/presubmission/learningcurve-rs.png", dpi=300)

# %%
plt.figure(figsize=(6,4))
ax = plt.subplot(1,1,1)
ax.scatter(x,y, label="data", s=2)
y_pred = best_s.post_order_traverse_recursive(x)
ax.plot(x,y_pred,color='k', label="random search fit")
ax.set_xlabel("x")
ax.set_ylabel("y")
#ax.set_title(f"Random Search Best Fitting, MAE={best_mae:.4f}")
plt.legend(loc="lower right")
plt.savefig("output/presubmission/best-fitting-rs.png",dpi=300)

# %% [markdown]
# ## Test Symbolic Node

# %%
root = SymbolicNode()
a1 = SymbolicNode(1)
a2 = SymbolicNode(1)
b1 = SymbolicNode(2)
b2 = SymbolicNode(2)
b3 = SymbolicNode(2)
b4 = SymbolicNode(2)
c1 = SymbolicNode(1)
c2 = SymbolicNode(1)
c5 = SymbolicNode(1)
c7 = SymbolicNode(1)
root.setNode([operators[2], a1, a2])
a1.setNode([operators[2], b1, b2])
a2.setNode([operators[0], b3, b4])
b1.setNode([operators[2], c1, c2])
b3.setNode([operators[4], c5])
b4.setNode([operators[5], c7])
print(root)
#root.all_node_level_traverse()
#root.mutate_hoist()
#print(root)
c5.degree
print(root.all_node)
root.sort_degree()
root.mutate_point()
print(root)
# Out:
# (((x*x)*x)*(sin(x)+cos(x)))
# []
# 2
# 1-2
# (((x*x)*x)*((x+x)+cos(x)))

# %%
copy(None)

# %%
b = [1,2,3]
c= [2]
b+c[1]

# %%
np.add.nin

# %%
np.random.randint(10)
